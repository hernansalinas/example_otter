# %%
# Initialize Otter
import otter
grader = otter.Notebook("test.ipynb")

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from datascience import *
path="https://raw.githubusercontent.com/fundatosudea/material_20242/develop_otter"

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# Ingresa tu nombre  con apellido y número de carnet en las variables dadas más abajo:
# Ejemplo:
# ```python
# NombreApellidos="Lisa Simpson"
# NumeroCarnet="27182818"
# ```

# %%
NombreApellidos="Juana de Arco"
NumeroCarnet=str(np.e)
Email="juana.Arco@udea.edu.co"

# %%
grader.check("qt")
# Out:
# qt results: All test cases passed!

# %% [markdown]
# <!-- END QUESTION -->
#
# P1. Esta es una pregunta de pruena

# %%
characters_q1 = 5

# %%
grader.check("q1")
# Out:
# q1 results: All test cases passed!

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**
#
# These are some submission instructions.

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export(run_tests=True)
# Out:
# Running your submission against local test cases...
#
#
# Your submission received the following results when run against available test cases:
#
#     qt results: All test cases passed!
#
#     q1 results:
#         q1 - 1 result:
#             ❌ Test case failed
#             Trying:
#                 assert characters_q1 == 5
#             Expecting nothing
#             **********************************************************************
#             Line 1, in q1 0
#             Failed example:
#                 assert characters_q1 == 5
#             Exception raised:
#                 Traceback (most recent call last):
#                   File "/Users/neuman/anaconda3/envs/data8/lib/python3.10/doctest.py", line 1350, in __run
#                     exec(compile(example.source, filename, "single",
#                   File "<doctest q1 0[0]>", line 1, in <module>
#                     assert characters_q1 == 5
#                 AssertionError
#                     <p>
#                         Your submission has been exported. Click
#                         <a href="test_2024_08_25T07_09_05_564894.zip" download="test_2024_08_25T07_09_05_564894.zip" target="_blank">here</a> to download
#                         the zip file.
#                     </p>
